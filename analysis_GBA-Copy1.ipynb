# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib as mpl
import re
import os
import patsy

from matplotlib.colors import ListedColormap

import sklearn
from sklearn.neighbors import NearestNeighbors
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.preprocessing import PowerTransformer, RobustScaler, StandardScaler, MinMaxScaler
from sklearn.cluster import KMeans, DBSCAN, OPTICS
from esda.adbscan import ADBSCAN
from pysal.model import mgwr
from mgwr.sel_bw import Sel_BW

import random
random.seed(42)    # For reproducibility
np.random.seed(42) # For reproducibility

# Make numeric display a bit neater
pd.set_option('display.float_format', lambda x: '{:,.2f}'.format(x))

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

pd.set_option('display.max_rows', 300) # specifies number of rows to show
pd.options.display.float_format = '{:40,.4f}'.format # specifies default number format to 4 decimal places
plt.style.use('ggplot') # specifies that graphs should use ggplot styling
# %matplotlib inline

# %%
pip install mcdm
# Out:
# Requirement already satisfied: mcdm in /opt/conda/envs/sds2020/lib/python3.7/site-packages (1.2)
# Requirement already satisfied: numpy>=1.19.2 in /opt/conda/envs/sds2020/lib/python3.7/site-packages (from mcdm) (1.21.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
tfont = {'fontname':'Liberation Sans Narrow', 'horizontalalignment':'left'}
import math
from geopandas import GeoDataFrame
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler
import mcdm

# %%
##node1 bus stop count
GBA_area=gpd.read_file('metro_data/gba10/GBA_area_10.shp',encoding="utf-8")
GBA_station=gpd.read_file('metro_data/GBA/GBA_railstation.shp',encoding="gbk")
GBA_station_id = pd.read_csv('metro_data/GBA/GBA_station.csv',low_memory=False,
                 usecols=['WGS84_Lng','sid'])

# %%
gba_station=GBA_station[['站名简','WGS84_Lng','NL_NAME_2','geometry']]
GBA_station_id.rename(columns={'sid':'id'},inplace=True)
gba_station=pd.merge(gba_station,GBA_station_id,on='WGS84_Lng',how='left')
gba_station=gba_station.drop(['id'],axis=1)
gba_station['id']=gba_station.index.values+1
gba_area=pd.merge(gba_station,GBA_area,on='id',how='right')

# %%
gba_area=gba_area.drop(['geometry_x'],axis=1)
gba_area.rename(columns={'geometry_y':'geometry'},inplace=True)

# %%
gba_area = GeoDataFrame(gba_area, crs="EPSG:4326", geometry=gba_area.geometry)
gba_station = GeoDataFrame(gba_station, crs="EPSG:4326", geometry=gba_station.geometry)

# %%
gba_area.rename(columns={'站名简':'station_name'},inplace=True)
gba_station.rename(columns={'站名简':'station_name'},inplace=True)

# %%
gba_bus_station=gpd.read_file('metro_data/GBA/amap_bus_stops_gba.shp',encoding="utf-8")
gba_bus_station_count = gpd.sjoin(gba_bus_station, gba_area, how='right')
gba_bus_station_count_test = gba_bus_station_count.groupby(['id'])['stop_id'].agg(N_busStop_Count='count').reset_index()
gba_area = pd.merge(gba_area, gba_bus_station_count_test, on='id',how='left')

# %%
gba_area
# Out:
#    station_name                                WGS84_Lng NL_NAME_2  id  time  \
# 0           虎门站                                 113.6683       东莞市   1    10
# 33  POLYGON ((112.40356 23.12807, 112.40456 23.127...             1029
# 34  POLYGON ((112.63135 23.22802, 112.63196 23.227...               29
# 35  POLYGON ((113.20882 22.63269, 113.20929 22.631...              269
# 36  POLYGON ((113.24565 22.69223, 113.24571 22.691...              401
# 37  POLYGON ((113.27709 22.64662, 113.27734 22.645...              151
# 38  POLYGON ((113.40112 22.59331, 113.40158 22.584...              458
# 39  POLYGON ((113.42976 22.56529, 113.43034 22.563...              105
# 40  POLYGON ((113.48870 22.52171, 113.48895 22.520...              416
# 41  POLYGON ((113.53679 22.33589, 113.53695 22.333...             1832
# 42  POLYGON ((113.51105 22.29480, 113.51112 22.292...             2282
# 43  POLYGON ((113.57029 22.24990, 113.57110 22.249...              707
# 44  POLYGON ((113.52933 22.41843, 113.52964 22.413...              537
# 45  POLYGON ((112.44091 23.04488, 112.44147 23.039...              463
# 46  POLYGON ((112.93241 23.17869, 112.93286 23.177...              732
# 47  POLYGON ((112.95927 23.12364, 112.95931 23.123...               95
# 48  POLYGON ((112.95561 23.11973, 112.95590 23.117...              142
# 49  POLYGON ((113.00613 23.11174, 113.00705 23.110...              637
# 50  POLYGON ((113.05758 23.09459, 113.05788 23.094...              740
# 51  POLYGON ((113.02502 23.09354, 113.02531 23.092...              721
# 52  POLYGON ((113.10366 23.07765, 113.10413 23.077...              756
# 53  POLYGON ((113.13228 23.13281, 113.13234 23.131...             1093
# 54  POLYGON ((113.12745 23.14394, 113.12774 23.142...             1144
# 55  POLYGON ((113.18579 23.38236, 113.18613 23.375...              183
# 56  POLYGON ((113.19449 23.32919, 113.19465 23.328...              372
# 57  POLYGON ((113.22899 23.27077, 113.22901 23.269...              152
# 58  POLYGON ((113.23389 23.27223, 113.23189 23.271...               84
# 59  POLYGON ((113.37672 23.16493, 113.37697 23.164...             1141
# 60  POLYGON ((113.73914 23.29329, 113.73949 23.290...              149
# 61  POLYGON ((113.82391 23.14462, 113.82454 23.144...              338
# 62  POLYGON ((113.87629 23.11948, 113.87634 23.119...              958
# 63  POLYGON ((113.88273 22.52195, 113.88306 22.521...              616
# 64  POLYGON ((113.93161 23.09378, 113.93273 23.092...              251
# 65  POLYGON ((113.91214 22.62994, 113.91663 22.625...             3043
# 66  POLYGON ((113.98424 23.07438, 113.98440 23.073...              598
# 67  POLYGON ((113.99550 22.99246, 113.99584 22.992...              823
# 68  POLYGON ((114.07290 22.90010, 114.07307 22.898...              551
# 69  POLYGON ((114.08459 22.83365, 114.08504 22.831...              810
# 70  POLYGON ((114.09775 22.79282, 114.09792 22.789...              244
# 71  POLYGON ((114.08891 22.63947, 114.08913 22.636...             1661
# 72  POLYGON ((114.09785 22.72675, 114.09848 22.719...              796
# 73  POLYGON ((114.11809 22.66644, 114.11910 22.665...              957

# %%
#范围内包含的地铁站数量
gba_metro_station=gpd.read_file('metro_data/gba10/GBA_metro_station.shp',encoding="utf-8")
gba_metro_station.set_crs(epsg=4326,inplace=True)
gba_metro_station_count = gpd.sjoin(gba_metro_station, gba_area, how='right')
gba_metro_station_count_test = gba_metro_station_count.groupby(['id'])['station_na'].agg(N_metro_Count='count').reset_index()
gba_area = pd.merge(gba_area, gba_metro_station_count_test, on='id',how='left')

# %%
#各站点每日服务车次
china_train = pd.read_excel('metro_data/GBA/china_station.xlsx')

# %%
china_train.head()
# Out:
#    station_no station_train_code train_class_name station_name arrive_time  \
# 0           1                 D1               动车           北京       18:07
# 1           2                 D1               动车          唐山北       19:18
# 2           3                 D1               动车          北戴河       20:16
# 3           4                 D1               动车           沈阳       23:23
# 4           5                 D1               动车          沈阳南       23:40
#
#   start_time stopover_time
# 0      18:07          ----
# 1      19:20           2分钟
# 2      20:18           2分钟
# 3      23:28           5分钟
# 4      23:40          ----

# %%
china_train_test = china_train.groupby(['station_name'])['station_no'].agg(N_train_Count='count').reset_index()

# %%
china_train_test.head()
# Out:
#   station_name  N_train_Count
# 0          一步滩              2
# 1          一面坡             11
# 2         一面坡北             10
# 3          一面山              3
# 4          七台河              6

# %%
gba_test=gba_area.copy()
gba_test["station_name"]= gba_test["station_name"].str.replace("站", "", case = False)

# %%
gba_test=pd.merge(gba_test,china_train_test,on='station_name',how='left')

# %%
gba_test['N_train_Count']=gba_test['N_train_Count'].fillna(0)

# %%
gba_test.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 74 entries, 0 to 73
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   station_name     74 non-null     object
#  1   WGS84_Lng        74 non-null     float64
#  2   NL_NAME_2        74 non-null     object
#  3   id               74 non-null     int64
#  4   time             74 non-null     int64
#  5   geometry         74 non-null     geometry
#  6   N_busStop_Count  74 non-null     int64
#  7   N_metro_Count    74 non-null     int64
#  8   N_train_Count    74 non-null     float64
# dtypes: float64(2), geometry(1), int64(4), object(2)
# memory usage: 5.8+ KB

# %%
gba_area=gba_test.copy()

# %%
#node-对外交通道路所占比例
road_total = pd.read_csv('metro_data/gba10/road_length.csv',low_memory=False, encoding="utf-8",
                 usecols=['road_length',"id"])
external_road = pd.read_csv('metro_data/gba10/external_length.csv',low_memory=False, encoding="utf-8",
                 usecols=['external_length',"id"])
external_road = pd.merge(external_road, road_total, on='id')
external_road['N_external_Coverage']=external_road.external_length/external_road.road_length
temp=external_road[['id','N_external_Coverage']]
gba_area=pd.merge(gba_area,temp,on='id',how='left')

# %%
gba_area
# Out:
#    station_name                                WGS84_Lng NL_NAME_2  id  time  \
# 0            虎门                                 113.6683       东莞市   1    10
# 1            东莞                                 113.8540       东莞市   2    10
# 2            常平                                 114.0013       东莞市   3    10
# 3           东莞东                                 114.0340       东莞市   4    10
# 4           樟木头                                 114.0622       东莞市   5    10
# 5           三水南                                 112.8663       佛山市   6    10
# 6            三水                                 112.8828       佛山市   7    10
# 7            佛山                                 113.0984       佛山市   8    10
# 8            碧江                                 113.2571       佛山市   9    10
# 9            北滘                                 113.2583       佛山市  10    10
# 10           顺德                                 113.2711       佛山市  11    10
# 11           容桂                                 113.3044       佛山市  12    10
# 12         顺德学院                                 113.3142       佛山市  13    10
# 13          广州北                                 113.1991       广州市  14    10
# 14           广州                                 113.2522       广州市  15    10
# 45  POLYGON ((112.44091 23.04488, 112.44147 23.039...              463
# 46  POLYGON ((112.93241 23.17869, 112.93286 23.177...              732
# 47  POLYGON ((112.95927 23.12364, 112.95931 23.123...               95
# 48  POLYGON ((112.95561 23.11973, 112.95590 23.117...              142
# 49  POLYGON ((113.00613 23.11174, 113.00705 23.110...              637
# 50  POLYGON ((113.05758 23.09459, 113.05788 23.094...              740
# 51  POLYGON ((113.02502 23.09354, 113.02531 23.092...              721
# 52  POLYGON ((113.10366 23.07765, 113.10413 23.077...              756
# 53  POLYGON ((113.13228 23.13281, 113.13234 23.131...             1093
# 54  POLYGON ((113.12745 23.14394, 113.12774 23.142...             1144
# 55  POLYGON ((113.18579 23.38236, 113.18613 23.375...              183
# 56  POLYGON ((113.19449 23.32919, 113.19465 23.328...              372
# 57  POLYGON ((113.22899 23.27077, 113.22901 23.269...              152
# 58  POLYGON ((113.23389 23.27223, 113.23189 23.271...               84
# 59  POLYGON ((113.37672 23.16493, 113.37697 23.164...             1141
# 60  POLYGON ((113.73914 23.29329, 113.73949 23.290...              149
# 61  POLYGON ((113.82391 23.14462, 113.82454 23.144...              338
# 62  POLYGON ((113.87629 23.11948, 113.87634 23.119...              958
# 63  POLYGON ((113.88273 22.52195, 113.88306 22.521...              616
# 64  POLYGON ((113.93161 23.09378, 113.93273 23.092...              251
# 65  POLYGON ((113.91214 22.62994, 113.91663 22.625...             3043
# 66  POLYGON ((113.98424 23.07438, 113.98440 23.073...              598
# 67  POLYGON ((113.99550 22.99246, 113.99584 22.992...              823
# 68  POLYGON ((114.07290 22.90010, 114.07307 22.898...              551
# 69  POLYGON ((114.08459 22.83365, 114.08504 22.831...              810
# 70  POLYGON ((114.09775 22.79282, 114.09792 22.789...              244
# 71  POLYGON ((114.08891 22.63947, 114.08913 22.636...             1661
# 72  POLYGON ((114.09785 22.72675, 114.09848 22.719...              796
# 73  POLYGON ((114.11809 22.66644, 114.11910 22.665...              957
#
#     N_metro_Count                            N_train_Count  \
# 0               2                                 143.0000
# 1               2                                 233.0000
# 2               0                                 187.0000
# 3               0                                  77.0000
# 4               0                                 178.0000
# 5               0                                  44.0000
# 6               0                                   1.0000
# 7               0                                  28.0000
# 8               0                                   2.0000
# 9               0                                  12.0000
# 10              0                                  66.0000
# 11              0                                  56.0000
# 12              0                                  14.0000
# 13              6                                  38.0000
# 14             13                                 212.0000
# 15              4                                 833.0000
# 16             18                                 250.0000
# 17              1                                  15.0000
# 18              0                                   0.0000
# 19              0                                  80.0000
# 20              0                                 127.0000
# 21              0                                  35.0000
# 22              0                                  85.0000
# 23              0                                   0.0000
# 24             24                                  18.0000
# 25             24                                  18.0000
# 26              0                                  22.0000
# 27              6                                  22.0000
# 28             25                                  23.0000
# 29              9                                 511.0000
# 30              0                                 222.0000
# 31              0                                  28.0000
# 32              0                                 105.0000
# 33              0                                  36.0000
# 34              0                                  23.0000
# 35              0                                  66.0000
# 36              0                                 170.0000
# 37              0                                  25.0000
# 38              0                                 159.0000
# 39              0                                   2.0000
# 40              0                                  53.0000
# 41              0                                  63.0000
# 42              0                                  16.0000
# 43              0                                  45.0000
# 44              0                                  10.0000
# 45              0                                 152.0000
# 46              0                                  39.0000
# 47              0                                   0.0000
# 48              0                                   0.0000
# 49              0                                  22.0000
# 50              0                                   0.0000
# 51              0                                   0.0000
# 52              0                                   0.0000
# 53              0                                   0.0000
# 54              0                                   0.0000
# 55              0                                   0.0000
# 56              0                                   0.0000
# 57              1                                   0.0000
# 58              0                                   0.0000
# 59              4                                   0.0000
# 60              0                                   0.0000
# 61              0                                   0.0000
# 62              2                                   0.0000
# 63              7                                   0.0000
# 64              0                                   0.0000
# 65              9                                   0.0000
# 66              0                                   0.0000
# 67              0                                   0.0000
# 68              0                                   0.0000
# 69              0                                   0.0000
# 70              1                                   0.0000
# 71              6                                   0.0000
# 72              3                                   0.0000
# 73              4                                   0.0000
#
#                         N_external_Coverage
# 0                                    0.5099
# 1                                    0.5333
# 2                                    0.2698
# 3                                    0.5157
# 4                                    0.6940
# 5                                    0.2455
# 6                                    0.3601
# 7                                    0.2328
# 8                                    0.2170
# 9                                    0.2347
# 10                                   0.4581
# 11                                   0.2888
# 12                                   0.7888
# 13                                   0.5790
# 14                                   0.4795
# 15                                   0.6012
# 16                                   0.3809
# 17                                   0.7139
# 18                                   0.6032
# 19                                   0.2660
# 20                                   1.0000
# 21                                   0.4281
# 22                                   0.1780
# 23                                   0.2398
# 24                                   0.1933
# 25                                   0.1933
# 26                                   0.5031
# 27                                   0.5383
# 28                                   0.3902
# 29                                   0.4734
# 30                                   0.7636
# 31                                   0.3015
# 32                                   0.8735
# 33                                   0.2429
# 34                                   0.0000
# 35                                   0.2536
# 36                                   0.6971
# 37                                   0.8623
# 38                                   0.7499
# 39                                   0.5190
# 40                                   0.3666
# 41                                   0.4403
# 42                                   0.4575
# 43                                   0.4577
# 44                                   0.2332
# 45                                   0.7857
# 46                                   0.6032
# 47                                   0.3033
# 48                                   0.0585
# 49                                   0.3022
# 50                                   0.2002
# 51                                   0.1916
# 52                                   0.1798
# 53                                   0.3105
# 54                                   0.5328
# 55                                   0.6772
# 56                                   0.7315
# 57                                   0.6676
# 58                                   0.6354
# 59                                   0.4537
# 60                                   0.9451
# 61                                   0.6320
# 62                                   0.4382
# 63                                   0.1021
# 64                                   0.6793
# 65                                   0.3582
# 66                                   0.5035
# 67                                   0.3938
# 68                                   0.8570
# 69                                   0.6356
# 70                                   0.0937
# 71                                   0.5326
# 72                                   0.2713
# 73                                   0.7403

# %%
#place-范围内人口总数
pop_area = pd.read_csv('metro_data/gba10/gba_pop.csv',low_memory=False, encoding="utf-8",
                 usecols=['pop',"id"])
fs_pop = pop_area.groupby(['id'])['pop'].agg(P_pop_sum='sum').reset_index()
gba_area=pd.merge(gba_area,fs_pop,on='id',how='left')

# %%
#node-交通用地占比/place-基本功能占比/非基本功能占比
basic_function = pd.read_csv('metro_data/gba10/gba_basic.csv',low_memory=False, encoding="utf-8",
                 usecols=['LU_area',"id"])
unbasic_function = pd.read_csv('metro_data/gba10/gba_unbasic.csv',low_memory=False, encoding="utf-8",
                 usecols=['LU_area',"id"])
transpotation_function = pd.read_csv('metro_data/gba10/gba_transportation.csv',low_memory=False, encoding="utf-8",
                 usecols=['LU_area',"id"])
area = pd.read_csv('metro_data/gba10/area.csv',low_memory=False, encoding="utf-8",
                 usecols=['area',"id"])
gba_area=pd.merge(area,gba_area,on='id',how='right')

# %%
basic_function = basic_function.groupby(['id'])['LU_area'].agg(basic_sum='sum').reset_index()
unbasic_function = unbasic_function.groupby(['id'])['LU_area'].agg(unbasic_sum='sum').reset_index()
transpotation_function = transpotation_function.groupby(['id'])['LU_area'].agg(transpotation_sum='sum').reset_index()

# %%
gba_area = pd.merge(gba_area, basic_function, on='id',how='left')
gba_area = pd.merge(gba_area, unbasic_function, on='id',how='left')
gba_area = pd.merge(gba_area, transpotation_function, on='id',how='left')

# %%
gba_area['N_transland_Cover']=gba_area.transpotation_sum/gba_area.area
gba_area['P_basic_Cover']=gba_area.basic_sum/gba_area.area
gba_area['P_unbasic_Cover']=gba_area.unbasic_sum/gba_area.area

# %%
gba_area= gba_area.drop(['transpotation_sum','basic_sum','unbasic_sum'],axis=1)

# %%
gba_area['N_transland_Cover'] = gba_area['N_transland_Cover'].fillna(0)
gba_area['P_basic_Cover'] = gba_area['P_basic_Cover'].fillna(0)
gba_area['P_unbasic_Cover'] = gba_area['P_unbasic_Cover'].fillna(0)

# %%
gba_area.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74 entries, 0 to 73
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   74 non-null     int64
#  1   area                 74 non-null     float64
#  2   station_name         74 non-null     object
#  3   WGS84_Lng            74 non-null     float64
#  4   NL_NAME_2            74 non-null     object
#  5   time                 74 non-null     int64
#  6   geometry             74 non-null     geometry
#  7   N_busStop_Count      74 non-null     int64
#  8   N_metro_Count        74 non-null     int64
#  9   N_train_Count        74 non-null     float64
#  10  N_external_Coverage  74 non-null     float64
#  11  P_pop_sum            74 non-null     int64
#  12  N_transland_Cover    74 non-null     float64
#  13  P_basic_Cover        74 non-null     float64
#  14  P_unbasic_Cover      74 non-null     float64
# dtypes: float64(7), geometry(1), int64(5), object(2)
# memory usage: 9.2+ KB

# %%
#Place-Degree of landuse mix---entropy 熵 Frank（2005）
landuse_area = pd.read_csv('metro_data/gba10/gba_landuse.csv',low_memory=False, encoding="utf-8",
                 usecols=['LU_area',"id",'Level1'])
test = landuse_area.groupby(['id','Level1'])['LU_area'].agg(LU_sum='sum').reset_index()
test1 = pd.pivot_table(test, index='id', columns='Level1', values='LU_sum')
test2 = pd.DataFrame(test1.to_records())

# %%
test_list=[]
for i in range (0,74):
    p=test2.loc[[i]].isna().sum().sum()
    test_list.append(p)

# %%
test2['na_vlaue']=test_list
test2['conf']=5
test2['n3']=test2.conf-test2.na_vlaue

# %%
test2['1'] = test2['1'].fillna(0)
test2['2'] = test2['2'].fillna(0)
test2['3'] = test2['3'].fillna(0)
test2['4'] = test2['4'].fillna(0)
test2['5'] = test2['5'].fillna(0)
test2['sum']=test2['1']+test2['2']+test2['3']+test2['4']+test2['5']

# %%
(test2['sum'] != 0).all()
# Out:
# True

# %%
LUM_list=[]
for i in range (0,74):
    if test2.at[i,'1']==0:
        t1=0
    else:
        t1=math.log(test2.at[i,'1']/test2.at[i,'sum'])
    if test2.at[i,'2']==0:
        t2=0
    else:
        t2=math.log(test2.at[i,'2']/test2.at[i,'sum'])
    if test2.at[i,'3']==0:
        t3=0
    else:
        t3=math.log(test2.at[i,'3']/test2.at[i,'sum'])
    if test2.at[i,'4']==0:
        t4=0
    else:
        t4=math.log(test2.at[i,'4']/test2.at[i,'sum'])
    if test2.at[i,'5']==0:
        t5=0
    else:
        t5=math.log(test2.at[i,'5']/test2.at[i,'sum'])
    p=(-1)*((test2.at[i,'1']/test2.at[i,'sum'])*t1
                   +(test2.at[i,'2']/test2.at[i,'sum'])*t2
                  +(test2.at[i,'3']/test2.at[i,'sum'])*t3
                  +(test2.at[i,'4']/test2.at[i,'sum'])*t4
                  +(test2.at[i,'5']/test2.at[i,'sum'])*t5)/math.log(test2.at[i,'n3'])
    LUM_list.append(p)

# %%
test2['P_LUM']=LUM_list
test2['P_LUM'] = test2['P_LUM'].fillna(0)

# %%
LUM_df = test2[['id', 'P_LUM']]
gba_area = pd.merge(gba_area, LUM_df, on='id',how='left')

# %%
#place2-Simpson Diversity Index(poi)
def simpson_di(data):

    """ Given a hash { 'species': count } , returns the Simpson Diversity Index
    
    >>> simpson_di({'a': 10, 'b': 20, 'c': 30,})
    0.3888888888888889
    """

    N = sum(data.values())
    
    def p(n, N):
        """ Relative abundance """
        if n is  0:
            return 0
        else:
            return (float(n)*(n-1))/(N*(N-1))

    
    return 1-sum(p(n, N) for n in data.values() if n is not 0)

# %%
gba_area = GeoDataFrame(gba_area, crs="EPSG:4326", geometry=gba_area.geometry)
gba_area['P_LUM'] = gba_area['P_LUM'].fillna(0)

# %%
gz_area2=gba_area.copy()

# %%
gz_poi_cy=gpd.read_file('metro_data/GBA/poi/餐饮.shp',encoding="utf-8")
gz_poi_total_count = gpd.sjoin(gz_poi_cy, gz_area2, how='right')
gz_poi_total_count_test = gz_poi_total_count.groupby(['id'])['gml_id'].agg(cy_Count='count').reset_index()
gz_area2 = pd.merge(gz_area2, gz_poi_total_count_test, on='id')

# %%
gz_poi_ds=gpd.read_file('metro_data/GBA/poi/大厦.shp',encoding="utf-8")
gz_poi_total_count = gpd.sjoin(gz_poi_ds, gz_area2, how='right')
gz_poi_total_count_test = gz_poi_total_count.groupby(['station_name'])['gml_id'].agg(ds_Count='count').reset_index()
gz_area2 = pd.merge(gz_area2, gz_poi_total_count_test, on='station_name')

# %%
gz_poi_mall=gpd.read_file('metro_data/GBA/poi/大型购物广场.shp',encoding="utf-8")
gz_poi_total_count = gpd.sjoin(gz_poi_mall, gz_area2, how='right')
gz_poi_total_count_test = gz_poi_total_count.groupby(['station_name'])['gml_id'].agg(mall_Count='count').reset_index()
gz_area2 = pd.merge(gz_area2, gz_poi_total_count_test, on='station_name')

# %%
gz_area2.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 74 entries, 0 to 73
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   74 non-null     int64
#  1   area                 74 non-null     float64
#  2   station_name         74 non-null     object
#  3   WGS84_Lng            74 non-null     float64
#  4   NL_NAME_2            74 non-null     object
#  5   time                 74 non-null     int64
#  6   geometry             74 non-null     geometry
#  7   N_busStop_Count      74 non-null     int64
#  8   N_metro_Count        74 non-null     int64
#  9   N_train_Count        74 non-null     float64
#  10  N_external_Coverage  74 non-null     float64
#  11  P_pop_sum            74 non-null     int64
#  12  N_transland_Cover    74 non-null     float64
#  13  P_basic_Cover        74 non-null     float64
#  14  P_unbasic_Cover      74 non-null     float64
#  15  P_LUM                74 non-null     float64
#  16  cy_Count             74 non-null     int64
#  17  ds_Count             74 non-null     int64
#  18  mall_Count           74 non-null     int64
# dtypes: float64(8), geometry(1), int64(8), object(2)
# memory usage: 11.6+ KB

# %%
gz_poi_gw=gpd.read_file('metro_data/gba10/poi/购物.shp',encoding="utf-8")
gz_poi_total_count = gpd.sjoin(gz_poi_gw, gz_area2, how='right')
gz_poi_total_count_test = gz_poi_total_count.groupby(['station_name'])['gml_id'].agg(gw_Count='count').reset_index()
gz_area2 = pd.merge(gz_area2, gz_poi_total_count_test, on='station_name')

# %%
gz_poi_jr=gpd.read_file('metro_data/GBA/poi/金融服务.shp',encoding="utf-8")
gz_poi_total_count = gpd.sjoin(gz_poi_jr, gz_area2, how='right')
gz_poi_total_count_test = gz_poi_total_count.groupby(['station_name'])['gml_id'].agg(jr_Count='count').reset_index()
gz_area2 = pd.merge(gz_area2, gz_poi_total_count_test, on='station_name')

# %%
gz_poi_ky=gpd.read_file('metro_data/GBA/poi/科研教育.shp',encoding="utf-8")
gz_poi_total_count = gpd.sjoin(gz_poi_ky, gz_area2, how='right')
gz_poi_total_count_test = gz_poi_total_count.groupby(['station_name'])['gml_id'].agg(ky_Count='count').reset_index()
gz_area2 = pd.merge(gz_area2, gz_poi_total_count_test, on='station_name')

# %%
gz_poi_ly=gpd.read_file('metro_data/GBA/poi/旅游.shp',encoding="utf-8")
gz_poi_total_count = gpd.sjoin(gz_poi_ly, gz_area2, how='right')
gz_poi_total_count_test = gz_poi_total_count.groupby(['station_name'])['gml_id'].agg(ly_Count='count').reset_index()
gz_area2 = pd.merge(gz_area2, gz_poi_total_count_test, on='station_name')

# %%
gz_poi_xs=gpd.read_file('metro_data/GBA/poi/休闲娱乐.shp',encoding="utf-8")
gz_poi_total_count = gpd.sjoin(gz_poi_xs, gz_area2, how='right')
gz_poi_total_count_test = gz_poi_total_count.groupby(['station_name'])['gml_id'].agg(xs_Count='count').reset_index()
gz_area2 = pd.merge(gz_area2, gz_poi_total_count_test, on='station_name')

# %%
gz_poi_zf=gpd.read_file('metro_data/GBA/poi/政府机关.shp',encoding="utf-8")
gz_poi_total_count = gpd.sjoin(gz_poi_zf, gz_area2, how='right')
gz_poi_total_count_test = gz_poi_total_count.groupby(['station_name'])['gml_id'].agg(zf_Count='count').reset_index()
gz_area2 = pd.merge(gz_area2, gz_poi_total_count_test, on='station_name')

# %%
gz_poi_zs=gpd.read_file('metro_data/GBA/poi/住宿.shp',encoding="utf-8")
gz_poi_total_count = gpd.sjoin(gz_poi_zs, gz_area2, how='right')
gz_poi_total_count_test = gz_poi_total_count.groupby(['station_name'])['gml_id'].agg(zs_Count='count').reset_index()
gz_area2 = pd.merge(gz_area2, gz_poi_total_count_test, on='station_name')

# %%
gba_area['P_poi_Diversity']=0.1

# %%
gz_area2.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 74 entries, 0 to 73
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   74 non-null     int64
#  1   area                 74 non-null     float64
#  2   station_name         74 non-null     object
#  3   WGS84_Lng            74 non-null     float64
#  4   NL_NAME_2            74 non-null     object
#  5   time                 74 non-null     int64
#  6   geometry             74 non-null     geometry
#  7   N_busStop_Count      74 non-null     int64
#  8   N_metro_Count        74 non-null     int64
#  9   N_train_Count        74 non-null     float64
#  10  N_external_Coverage  74 non-null     float64
#  11  P_pop_sum            74 non-null     int64
#  12  N_transland_Cover    74 non-null     float64
#  13  P_basic_Cover        74 non-null     float64
#  14  P_unbasic_Cover      74 non-null     float64
#  15  P_LUM                74 non-null     float64
#  16  cy_Count             74 non-null     int64
#  17  ds_Count             74 non-null     int64
#  18  mall_Count           74 non-null     int64
#  19  gw_Count             74 non-null     int64
#  20  jr_Count             74 non-null     int64
#  21  ky_Count             74 non-null     int64
#  22  ly_Count             74 non-null     int64
#  23  xs_Count             74 non-null     int64
#  24  zf_Count             74 non-null     int64
#  25  zs_Count             74 non-null     int64
# dtypes: float64(8), geometry(1), int64(15), object(2)
# memory usage: 15.6+ KB

# %%
for i in range(0,74):
    poi_dic={'a':gz_area2['cy_Count'][i],'b':gz_area2['ds_Count'][i],'c':gz_area2['mall_Count'][i],
             'd':gz_area2['gw_Count'][i],'e':gz_area2['jr_Count'][i],'f':gz_area2['ky_Count'][i],
             'g':gz_area2['ly_Count'][i],'h':gz_area2['xs_Count'][i],'i':gz_area2['zf_Count'][i],
             'j':gz_area2['zs_Count'][i]}
    gba_area['P_poi_Diversity'][i]=simpson_di(poi_dic)
# Out:
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in double_scalars

# %%
gba_area['P_poi_Diversity'] = gba_area['P_poi_Diversity'].fillna(0)

# %%
gba_area.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 74 entries, 0 to 73
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   74 non-null     int64
#  1   area                 74 non-null     float64
#  2   station_name         74 non-null     object
#  3   WGS84_Lng            74 non-null     float64
#  4   NL_NAME_2            74 non-null     object
#  5   time                 74 non-null     int64
#  6   geometry             74 non-null     geometry
#  7   N_busStop_Count      74 non-null     int64
#  8   N_metro_Count        74 non-null     int64
#  9   N_train_Count        74 non-null     float64
#  10  N_external_Coverage  74 non-null     float64
#  11  P_pop_sum            74 non-null     int64
#  12  N_transland_Cover    74 non-null     float64
#  13  P_basic_Cover        74 non-null     float64
#  14  P_unbasic_Cover      74 non-null     float64
#  15  P_LUM                74 non-null     float64
#  16  P_poi_Diversity      74 non-null     float64
# dtypes: float64(9), geometry(1), int64(5), object(2)
# memory usage: 12.9+ KB

# %%
###测量correlation
gba_cor2=gba_area.copy()
gba_cor2= gba_cor2.drop(['id','WGS84_Lng','NL_NAME_2','geometry','station_name','area','time'],axis=1)

# %%
corrMatrix=gba_cor2.corr()
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corrMatrix, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
plot1=sns.heatmap(corrMatrix,  cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
plot1.figure.savefig("corr_gba.png",dpi=300)

# %%
gba_area.to_csv('gba_all_variables.csv',encoding='utf-8',index=False)

# %%
#分析
gba_PCA=gba_area.copy()

# %%
gba_area.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 74 entries, 0 to 73
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   74 non-null     int64
#  1   area                 74 non-null     float64
#  2   station_name         74 non-null     object
#  3   WGS84_Lng            74 non-null     float64
#  4   NL_NAME_2            74 non-null     object
#  5   time                 74 non-null     int64
#  6   geometry             74 non-null     geometry
#  7   N_busStop_Count      74 non-null     int64
#  8   N_metro_Count        74 non-null     int64
#  9   N_train_Count        74 non-null     float64
#  10  N_external_Coverage  74 non-null     float64
#  11  P_pop_sum            74 non-null     int64
#  12  N_transland_Cover    74 non-null     float64
#  13  P_basic_Cover        74 non-null     float64
#  14  P_unbasic_Cover      74 non-null     float64
#  15  P_LUM                74 non-null     float64
#  16  P_poi_Diversity      74 non-null     float64
# dtypes: float64(9), geometry(1), int64(5), object(2)
# memory usage: 12.9+ KB

# %%
#PCA for Node
features_N = ['N_busStop_Count', 'N_train_Count', 'N_metro_Count','N_external_Coverage','N_transland_Cover'
           ]
# Separating out the features
x_N = gba_PCA.loc[:, features_N].values
# Standardizing the features
x_N =MinMaxScaler().fit_transform(x_N)#MinMaxScaler/StandardScaler

#PCA for Plcae
features_P = ['P_poi_Diversity', 'P_pop_sum', 'P_basic_Cover', 'P_unbasic_Cover','P_LUM'
           ]
# Separating out the features
x_P = gba_PCA.loc[:, features_P].values
# Standardizing the features
x_P = MinMaxScaler().fit_transform(x_P)

# %%
Node_arry=mcdm.weighting.critic(x_N)
Node_wgt=Node_arry.tolist()
Place_arry=mcdm.weighting.critic(x_P)
Place_wgt=Place_arry.tolist()

# %%
###测量correlation
gba_index=gba_area.copy()
gba_index= gba_index.drop(['id','WGS84_Lng','NL_NAME_2','geometry','station_name','area','time'],axis=1)

# %%
scaler = MinMaxScaler()
# fit and transform the data
gz_norm = pd.DataFrame(scaler.fit_transform(gba_index), columns=gba_index.columns)

# %%
#计算各维度index
gz_norm['Node_index']=gz_norm.N_busStop_Count*Node_wgt[0]+gz_norm.N_train_Count*Node_wgt[1]+gz_norm.N_metro_Count*Node_wgt[2]+gz_norm.N_external_Coverage*Node_wgt[3]+gz_norm.N_transland_Cover*Node_wgt[4]
gz_norm['Place_index']=gz_norm.P_poi_Diversity*Place_wgt[0]+gz_norm.P_pop_sum*Place_wgt[1]+gz_norm.P_basic_Cover*Node_wgt[2]+gz_norm.P_unbasic_Cover*Place_wgt[3]+gz_norm.P_LUM*Place_wgt[4]

# %%
gz_final=gz_norm[['Node_index','Place_index']]
gz_final['id']=gz_final.index.values+1
# Out:
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
gba_final_area=pd.merge(gba_area,gz_final,on='id',how='left')
gz_temp=gba_final_area[['id','Node_index','Place_index']]

# %%
gba_station.head()
# Out:
#   station_name                                WGS84_Lng NL_NAME_2  \
# 0          虎门站                                 113.6683       东莞市
# 1          东莞站                                 113.8540       东莞市
# 2          常平站                                 114.0013       东莞市
# 3         东莞东站                                 114.0340       东莞市
# 4         樟木头站                                 114.0622       东莞市
#
#                           geometry  id
# 0  MULTIPOINT (113.66829 22.86435)   1
# 1  MULTIPOINT (113.85398 23.09034)   2
# 2  MULTIPOINT (114.00127 22.98583)   3
# 3  MULTIPOINT (114.03395 22.96989)   4
# 4  MULTIPOINT (114.06222 22.90412)   5

# %%
gba_final_station=pd.merge(gba_station,gz_temp,on='id',how='right')

# %%
gba_final_area
# Out:
#     id                                     area station_name  \
# 0    1                          28,543,484.9000           虎门
# 1    2                          24,882,033.0900           东莞
# 2    3                          15,477,331.8300           常平
# 3    4                          13,979,129.8700          东莞东
# 4    5                           9,466,952.3740          樟木头
# 5    6                          10,051,787.8700          三水南
# 6    7                          17,134,101.1600           三水
# 7    8                          17,414,339.6100           佛山
# 8    9                          30,511,000.2800           碧江
# 9   10                          11,901,840.1700           北滘
# 10  11                          50,785,590.9300           顺德
# 11  12                          24,093,044.4900           容桂
# 12  13                           3,006,223.9620         顺德学院
# 13  14                          27,585,364.3600          广州北
# 14  15                          22,307,019.8500           广州
# 15  16                          17,607,885.8400          广州南
# 16  17                          16,505,518.4500          广州东
# 17  18                           5,757,184.5600           庆盛
# 18  19                          20,415,105.7600          惠州西
# 19  20                          27,442,953.5600           惠州
# 20  21                           2,109,752.8990          惠州南
# 21  22                           3,386,285.0680           惠东
# 22  23                          24,957,973.2500           新会
# 23  24                          46,213,047.9200           江门
# 24  25                          32,438,256.2400           南头
# 27  28                          19,374,440.6500          深圳西
# 28  29                          19,178,747.4200          光明城
# 29  30                          13,459,950.3500          深圳北
# 30  31                          12,845,262.5800           深圳
# 31  32                           9,508,670.5880          深圳东
# 32  33                          10,898,892.9700         深圳坪山
# 33  34                          25,302,809.6600           怀集
# 34  35                           4,075,379.9380           广宁
# 35  36                          19,680,395.4100           肇庆
# 36  37                          13,753,731.9800          肇庆东
# 37  38                          11,088,686.9700           古镇
# 38  39                          22,061,819.3000           小榄
# 39  40                           6,292,938.2010           东升
# 40  41                          25,112,656.7200          中山北
# 41  42                          31,826,709.9900           中山
# 42  43                          34,027,589.3400           南朗
# 43  44                          13,759,521.0300           明珠
# 44  45                          21,539,138.2600           前山
# 45  46                          10,677,718.9000           珠海
# 53                                 113.0350       佛山市    10
# 54                                 113.0627       佛山市    10
# 55                                 113.1043       佛山市    10
# 56                                 113.1524       佛山市    10
# 57                                 113.2038       广州市    10
# 58                                 113.2155       广州市    10
# 59                                 113.2200       广州市    10
# 60                                 113.2229       广州市    10
# 61                                 113.4117       广州市    10
# 62                                 113.7731       广州市    10
# 63                                 113.8349       东莞市    10
# 64                                 113.8763       东莞市    10
# 65                                 113.8917       深圳市    10
# 66                                 113.9076       东莞市    10
# 67                                 113.9311       深圳市    10
# 68                                 113.9522       东莞市    10
# 69                                 114.0175       东莞市    10
# 70                                 114.0799       东莞市    10
# 71                                 114.0926       东莞市    10
# 72                                 114.1028       东莞市    10
# 73                                 114.1089       深圳市    10
#
#                                              geometry  N_busStop_Count  \
# 0   POLYGON ((113.68229 22.93803, 113.68256 22.932...              452
# 1   POLYGON ((113.85498 23.11751, 113.85728 23.115...             1219
# 2   POLYGON ((113.97227 23.01403, 113.97505 23.012...              843
# 3   POLYGON ((114.03295 22.98198, 114.03399 22.980...              556
# 4   POLYGON ((114.06922 22.93304, 114.06928 22.931...              418
# 5   POLYGON ((112.87428 23.17550, 112.87445 23.173...              144
# 6   POLYGON ((112.88176 23.20208, 112.88209 23.200...             1872
# 7   POLYGON ((113.09842 23.08493, 113.09904 23.081...             1643
# 8   POLYGON ((113.26212 22.98563, 113.26412 22.985...              620
# 9   POLYGON ((113.25132 22.94327, 113.25169 22.941...              299
# 10  POLYGON ((113.25509 22.93790, 113.25690 22.936...             1345
# 11  POLYGON ((113.30240 22.78465, 113.30292 22.783...              613
# 12  POLYGON ((113.31622 22.82642, 113.31722 22.825...               34
# 13  POLYGON ((113.20414 23.41268, 113.20412 23.412...             1741
# 14  POLYGON ((113.25524 23.18652, 113.25559 23.184...             4568
# 15  POLYGON ((113.24012 23.02716, 113.24068 23.025...              334
# 16  POLYGON ((113.34217 23.17970, 113.34274 23.179...             3117
# 17  POLYGON ((113.46410 22.88596, 113.46510 22.885...              212
# 18  POLYGON ((114.33161 23.14157, 114.33225 23.141...              659
# 19  POLYGON ((114.39662 23.19747, 114.39714 23.196...              921
# 20  POLYGON ((114.49460 22.84282, 114.49466 22.840...               31
# 21  POLYGON ((114.77093 22.88594, 114.77105 22.885...               33
# 22  POLYGON ((113.05572 22.58980, 113.05694 22.588...              896
# 23  POLYGON ((113.10280 22.60972, 113.10315 22.608...             1445
# 24  POLYGON ((113.88065 22.57919, 113.88091 22.578...             3093
# 27  POLYGON ((114.00192 22.64407, 114.00292 22.643...             1725
# 28  POLYGON ((114.11507 22.57745, 114.11568 22.577...             3425
# 29  POLYGON ((114.11769 22.62802, 114.11771 22.627...             2026
# 30  POLYGON ((114.35341 22.73544, 114.35364 22.734...             1475
# 31  POLYGON ((112.17122 23.92843, 112.17087 23.927...               45
# 32  POLYGON ((112.43041 23.63866, 112.43051 23.638...               86
# 33  POLYGON ((112.40356 23.12807, 112.40456 23.127...             1029
# 34  POLYGON ((112.63135 23.22802, 112.63196 23.227...               29
# 37                                   0.2324
# 38                                   0.5243
# 39                                   0.2602
# 40                                   0.1446
# 41                                   0.2886
# 42                                   0.2538
# 43                                   0.2006
# 44                                   0.0846
# 45                                   0.4984
# 46                                   0.4489
# 47                                   0.7400
# 48                                   0.7497
# 49                                   0.7095
# 50                                   0.7431
# 51                                   0.7352
# 52                                   0.6182
# 53                                   0.6319
# 54                                   0.5593
# 55                                   0.1047
# 56                                   0.6654
# 57                                   0.5900
# 58                                   0.6514
# 59                                   0.4658
# 60                                   0.3257
# 61                                   0.3031
# 62                                   0.5713
# 63                                   0.2604
# 64                                   0.5283
# 65                                   0.1647
# 66                                   0.6182
# 67                                   0.2988
# 68                                   0.1979
# 69                                   0.1451
# 70                                   0.3558
# 71                                   0.0323
# 72                                   0.1500
# 73                                   0.0956
#
#                             P_unbasic_Cover  \
# 0                                    0.3546
# 1                                    0.2056
# 2                                    0.4634
# 3                                    0.4037
# 4                                    0.7588
# 5                                    0.3624
# 6                                    0.5566
# 7                                    0.3351
# 8                                    0.3639
# 9                                    0.1889
# 10                                   0.2212
# 11                                   0.1602
# 12                                   0.1822
# 13                                   0.2609
# 14                                   0.3550
# 15                                   0.1844
# 16                                   0.6099
# 17                                   0.2711
# 18                                   0.3527
# 19                                   0.1409
# 20                                   0.5354
# 21                                   0.1193
# 22                                   0.3151
# 23                                   0.2258
# 24                                   0.3101
# 27                                   0.5600
# 28                                   0.4808
# 29                                   0.7102
# 30                                   0.2754
# 31                                   0.1680
# 32                                   0.0287
# 33                                   0.0694
# 34                                   0.0000
# 35                                   0.3845
# 36                                   0.0554
# 37                                   0.0018
# 38                                   0.2882
# 39                                   0.3916
# 40                                   0.4355
# 41                                   0.5269
# 42                                   0.4558
# 43                                   0.3225
# 44                                   0.5902
# 45                                   0.1261
# 46                                   0.2660
# 47                                   0.1254
# 48                                   0.0654
# 49                                   0.0897
# 50                                   0.1234
# 51                                   0.1306
# 52                                   0.1881
# 53                                   0.1379
# 54                                   0.1113
# 55                                   0.0318
# 56                                   0.0069
# 57                                   0.2430
# 58                                   0.1964
# 59                                   0.3441
# 60                                   0.1925
# 61                                   0.3557
# 62                                   0.2434
# 63                                   0.2573
# 64                                   0.2214
# 65                                   0.5230
# 66                                   0.2023
# 67                                   0.5329
# 68                                   0.5724
# 69                                   0.7210
# 70                                   0.5283
# 71                                   0.6786
# 72                                   0.6985
# 73                                   0.7177
#
#                                       P_LUM  \
# 0                                    0.7044
# 1                                    0.7049
# 2                                    0.8546
# 3                                    0.8036
# 4                                    0.2380
# 5                                    0.9526
# 6                                    0.8672
# 7                                    0.9269
# 8                                    0.7755
# 9                                    0.4669
# 10                                   0.7392
# 11                                   0.6630
# 12                                   0.8834
# 13                                   0.8872
# 14                                   0.9631
# 15                                   0.9525
# 16                                   0.6564
# 17                                   0.8367
# 18                                   0.5745
# 19                                   0.7399
# 20                                   0.7440
# 21                                   0.9945
# 22                                   0.7196
# 23                                   0.6492
# 24                                   0.7555
# 27                                   0.6528
# 28                                   0.7650
# 29                                   0.4809
# 30                                   0.7849
# 31                                   0.7455
# 32                                   0.6011
# 33                                   0.4551
# 34                                   0.9105
# 35                                   0.7535
# 36                                   0.6417
# 37                                   0.3667
# 38                                   0.6493
# 39                                   0.7172
# 40                                   0.7306
# 41                                   0.7656
# 42                                   0.8147
# 43                                   0.8992
# 44                                   0.7260
# 45                                   0.5616
# 46                                   0.7595
# 47                                   0.3998
# 48                                   0.2350
# 49                                   0.3927
# 50                                   0.4683
# 51                                   0.4910
# 52                                   0.6981
# 53                                   0.7057
# 54                                   0.8572
# 55                                   0.3335
# 56                                   0.4578
# 57                                   0.7827
# 58                                   0.6551
# 59                                   0.8440
# 60                                   0.8253
# 61                                   0.8422
# 62                                   0.6156
# 63                                   0.7696
# 64                                   0.6350
# 65                                   0.7819
# 66                                   0.6679
# 67                                   0.7880
# 68                                   0.8048
# 69                                   0.7440
# 70                                   0.7982
# 71                                   0.5092
# 72                                   0.6797
# 73                                   0.6380
#
#                             P_poi_Diversity  \
# 0                                    0.7868
# 1                                    0.7756
# 2                                    0.7689
# 3                                    0.7999
# 4                                    0.7903
# 5                                    0.7869
# 6                                    0.7860
# 7                                    0.7895
# 8                                    0.8049
# 9                                    0.7127
# 10                                   0.7901
# 11                                   0.7858
# 12                                   0.6667
# 13                                   0.7877
# 14                                   0.8133
# 15                                   0.7301
# 16                                   0.7880
# 17                                   0.8623
# 18                                   0.8044
# 19                                   0.8086
# 20                                   0.0000
# 21                                   0.8901
# 22                                   0.7984
# 23                                   0.8207
# 24                                   0.8069
# 27                                   0.7595
# 28                                   0.7796
# 29                                   0.7535
# 30                                   0.8115
# 31                                   0.7709
# 32                                   0.7934
# 33                                   0.7635
# 34                                   0.0000
# 35                                   0.8013
# 36                                   0.7960
# 37                                   0.7765
# 38                                   0.7497
# 39                                   0.7102
# 40                                   0.8249
# 41                                   0.8052
# 42                                   0.7834
# 43                                   0.7551
# 44                                   0.8097
# 45                                   0.8233
# 46                                   0.8070
# 47                                   0.8187
# 48                                   0.8150
# 49                                   0.7875
# 50                                   0.7897
# 51                                   0.7866
# 52                                   0.7910
# 53                                   0.7957
# 54                                   0.7691
# 55                                   0.8270
# 56                                   0.7800
# 57                                   0.6932
# 58                                   0.6570
# 59                                   0.7590
# 60                                   0.7980
# 61                                   0.8017
# 62                                   0.7918
# 63                                   0.7381
# 64                                   0.7870
# 65                                   0.7739
# 66                                   0.7867
# 67                                   0.7797
# 68                                   0.7562
# 69                                   0.7581
# 70                                   0.8080
# 71                                   0.7486
# 72                                   0.7852
# 73                                   0.7477
#
#                                  Node_index  \
# 0                                    0.1904
# 1                                    0.2739
# 2                                    0.1385
# 3                                    0.1679
# 4                                    0.2249
# 5                                    0.0753
# 6                                    0.1725
# 7                                    0.1514
# 8                                    0.0819
# 9                                    0.0741
# 10                                   0.1860
# 11                                   0.1089
# 12                                   0.2077
# 13                                   0.3013
# 14                                   0.4894
# 15                                   0.4083
# 16                                   0.4315
# 17                                   0.2055
# 18                                   0.1816
# 19                                   0.2057
# 20                                   0.2846
# 21                                   0.1154
# 22                                   0.0998
# 23                                   0.1236
# 24                                   0.3897
# 27                                   0.2694
# 28                                   0.4623
# 29                                   0.3760
# 30                                   0.3084
# 31                                   0.0824
# 32                                   0.2435
# 33                                   0.1119
# 34                                   0.0297
# 35                                   0.0964
# 36                                   0.3262
# 37                                   0.3955
# 38                                   0.2383
# 39                                   0.1365
# 40                                   0.1223
# 41                                   0.2023
# 42                                   0.2205
# 43                                   0.1681
# 44                                   0.0834
# 45                                   0.2465
# 46                                   0.1913
# 47                                   0.0802
# 48                                   0.0199
# 49                                   0.1074
# 50                                   0.0821
# 51                                   0.0791
# 52                                   0.0796
# 53                                   0.1357
# 54                                   0.2233
# 55                                   0.3712
# 56                                   0.2668
# 57                                   0.1840
# 58                                   0.1644
# 59                                   0.2000
# 60                                   0.2463
# 61                                   0.2237
# 62                                   0.1809
# 63                                   0.1123
# 64                                   0.1829
# 65                                   0.2993
# 66                                   0.1533
# 67                                   0.1358
# 68                                   0.2413
# 69                                   0.1962
# 70                                   0.0417
# 71                                   0.2618
# 72                                   0.1280
# 73                                   0.2630
#
#                                 Place_index
# 0                                    0.5002
# 1                                    0.4456
# 2                                    0.5240
# 3                                    0.5153
# 4                                    0.3630
# 5                                    0.5065
# 6                                    0.5283
# 7                                    0.5283
# 8                                    0.5017
# 9                                    0.3831
# 10                                   0.4306
# 11                                   0.4823
# 12                                   0.3829
# 13                                   0.5324
# 14                                   0.6071
# 15                                   0.4559
# 16                                   0.4987
# 17                                   0.4870
# 18                                   0.3462
# 19                                   0.4128
# 20                                   0.3310
# 21                                   0.3899
# 22                                   0.4831
# 23                                   0.4653
# 24                                   0.4195
# 27                                   0.4123
# 28                                   0.4890
# 29                                   0.4336
# 30                                   0.4862
# 31                                   0.4364
# 32                                   0.3216
# 33                                   0.3981
# 34                                   0.2236
# 35                                   0.4893
# 36                                   0.3612
# 37                                   0.2050
# 38                                   0.4616
# 39                                   0.4232
# 40                                   0.4206
# 41                                   0.5190
# 42                                   0.4989
# 43                                   0.4525
# 44                                   0.4506
# 45                                   0.3829
# 46                                   0.4612
# 47                                   0.4061
# 48                                   0.3475
# 49                                   0.3821
# 50                                   0.4236
# 51                                   0.4287
# 52                                   0.4709
# 53                                   0.4836
# 54                                   0.4801
# 55                                   0.1767
# 56                                   0.3602
# 57                                   0.4838
# 58                                   0.4476
# 59                                   0.5190
# 60                                   0.4149
# 61                                   0.4727
# 62                                   0.4593
# 63                                   0.3986
# 64                                   0.4372
# 65                                   0.5054
# 66                                   0.4742
# 67                                   0.5149
# 68                                   0.4983
# 69                                   0.5201
# 70                                   0.5319
# 71                                   0.4215
# 72                                   0.4975
# 73                                   0.4728

# %%
gba_final_station.drop([25,26],axis=0,inplace=True)
gba_final_area.drop([25,26],axis=0,inplace=True)

# %%
gba_final_station.to_file("gba_station_withindex.shp")
gba_final_area.to_file("gba_area_withindex.shp")
